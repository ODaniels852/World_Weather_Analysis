# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
print(cities)
# Out:
# ['paranaiba', 'bowen', 'atuona', 'brigantine', 'port alfred', 'blytheville', 'gizo', 'taolanaro', 'saleaula', 'aswan', 'saint-philippe', 'catamarca', 'hilo', 'ribeira grande', 'ushuaia', 'tasiilaq', 'skalistyy', 'punta arenas', 'vaitupu', 'sorland', 'mataura', 'lebu', 'ancud', 'geraldton', 'savannah bight', 'adrar', 'svetlogorsk', 'cabo san lucas', 'hermanus', 'yellowknife', 'jiddah', 'nizhniy kuranakh', 'barentsburg', 'samusu', 'port augusta', 'vaini', 'talnakh', 'jamestown', 'victoria', 'beyla', 'cape town', 'rikitea', 'thompson', 'busselton', 'qaanaaq', 'nanakuli', 'wad rawah', 'kismayo', 'leningradskiy', 'port pirie', 'hobart', 'la ronge', 'kemijarvi', 'nyurba', 'parabel', 'bambous virieux', 'belushya guba', 'mahebourg', 'butaritari', 'puerto ayora', 'marcona', 'tuktoyaktuk', 'port elizabeth', 'coahuayana', 'new norfolk', 'hasaki', 'phetchabun', 'kandrian', 'minudasht', 'sitka', 'bredasdorp', 'alta floresta', 'bluff', 'kruisfontein', 'sentyabrskiy', 'albany', 'mbini', 'tiksi', 'karratha', 'sept-iles', 'iranshahr', 'grindavik', 'luderitz', 'whitehorse', 'guantanamo', 'camana', 'kulu', 'gat', 'yulara', 'raga', 'namibe', 'wageningen', 'pevek', 'kolvereid', 'bethel', 'kavieng', 'attawapiskat', 'pemangkat', 'sakaraha', 'erzin', 'atherton', 'kailua', 'marawi', 'pisco', 'banda aceh', 'chagda', 'severnyy', 'mys shmidta', 'vardo', 'ust-omchug', 'tripoli', 'saint-pierre', 'piopio', 'hami', 'port hawkesbury', 'zaria', 'naze', 'ahipara', 'eureka', 'carnarvon', 'avarua', 'coquimbo', 'pianco', 'karla', 'hovd', 'marsh harbour', 'faanui', 'araouane', 'longlac', 'kralendijk', 'vao', 'pangani', 'gravdal', 'bilma', 'panjab', 'vila velha', 'tsihombe', 'palestina', 'lagoa', 'bucerias', 'san carlos de bariloche', 'fortuna', 'kapit', 'artyk', 'klaksvik', 'suez', 'praya', 'matagalpa', 'manokwari', 'isabela', 'castro', 'kupang', 'khatanga', 'college', 'wilmington', 'umzimvubu', 'muscat', 'anadyr', 'karkaralinsk', 'pangnirtung', 'port hedland', 'tawnat', 'oranjemund', 'georgetown', 'chokurdakh', 'sangar', 'vostok', 'seoul', 'loukhi', 'kyzyl-suu', 'sayyan', 'arraial do cabo', 'oyama', 'nguiu', 'sedalia', 'salalah', 'puerto colombia', 'aklavik', 'fort nelson', 'port blair', 'egvekinot', 'coos bay', 'axim', 'terrace', 'elda', 'east london', 'chuy', 'illoqqortoormiut', 'torbay', 'los llanos de aridane', 'cadiz', 'kapaa', 'ostrovnoy', 'airai', 'tefe', 'tuatapere', 'alice town', 'surovikino', 'kissidougou', 'smithers', 'dikson', 'port hardy', 'uvat', 'auki', 'broome', 'fukue', 'thinadhoo', 'tomari', 'dombarovskiy', 'kodiak', 'bilibino', 'solone', 'hamilton', 'barabai', 'san luis', 'grand-santi', 'wewak', 'sibolga', 'zhengjiatun', 'upernavik', 'byron bay', 'lavrentiya', 'port lincoln', 'maykor', 'jablah', 'faya', 'brae', 'yokadouma', 'arys', 'khlevnoye', 'olot', 'hay river', 'aiken', 'oxford', 'guanica', 'bengkulu', 'itoman', 'umm kaddadah', 'shestakovo', 'nikolskoye', 'palasa', 'viligili', 'davila', 'tres arroyos', 'kaitangata', 'dingle', 'corn island', 'lisakovsk', 'borgarnes', 'kohat', 'adre', 'karpathos', 'portland', 'esperance', 'vallenar', 'afua', 'viking', 'cherskiy', 'saskylakh', 'cururupu', 'nuuk', 'shingu', 'isangel', 'manono', 'lompoc', 'srednekolymsk', 'macaboboni', 'saint george', 'kuryk', 'lorengau', 'longyearbyen', 'iqaluit', 'vanavara', 'letlhakane', 'naron', 'bargal', 'kidal', 'goksun', 'bekhtery', 'mount gambier', 'norman wells', 'cairns', 'mullaitivu', 'abu samrah', 'manaure', 'ko samui', 'numan', 'neuquen', 'caravelas', 'cabedelo', 'amderma', 'belmonte', 'bathsheba', 'kavaratti', 'richards bay', 'raudeberg', 'sezze', 'yar-sale', 'choix', 'fairbanks', 'yangjiang', 'amga', 'abu road', 'loei', 'zhigansk', 'xique-xique', 'bolungarvik', 'bandarbeyla', 'quatre cocos', 'chardara', 'hwange', 'ixtapa', 'hecun', 'menongue', 'mouila', 'cidreira', 'sola', 'toliary', 'dunedin', 'bedford', 'nome', 'tono', 'ponta do sol', 'frolovo', 'mitsamiouli', 'lephepe', 'nangong', 'astana', 'vestmannaeyjar', 'makakilo city', 'zhangjiakou', 'flin flon', 'khonuu', ...

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | paranaiba
# Processing Record 2 of Set 1 | bowen
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | brigantine
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | blytheville
# Processing Record 7 of Set 1 | gizo
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | aswan
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | catamarca
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | sorland
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | savannah bight
# Processing Record 26 of Set 1 | adrar
# Processing Record 27 of Set 1 | svetlogorsk
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 1 | nizhniy kuranakh
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 1 | port augusta
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | beyla
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | nanakuli
# Processing Record 47 of Set 1 | wad rawah
# Processing Record 48 of Set 1 | kismayo
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | port pirie
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | la ronge
# Processing Record 3 of Set 2 | kemijarvi
# Processing Record 4 of Set 2 | nyurba
# Processing Record 5 of Set 2 | parabel
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | coahuayana
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | phetchabun
# Processing Record 18 of Set 2 | kandrian
# Processing Record 19 of Set 2 | minudasht
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | alta floresta
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | mbini
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | karratha
# Processing Record 30 of Set 2 | sept-iles
# Processing Record 31 of Set 2 | iranshahr
# Processing Record 32 of Set 2 | grindavik
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | whitehorse
# Processing Record 35 of Set 2 | guantanamo
# Processing Record 36 of Set 2 | camana
# Processing Record 37 of Set 2 | kulu
# Processing Record 38 of Set 2 | gat
# Processing Record 39 of Set 2 | yulara
# Processing Record 40 of Set 2 | raga
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | wageningen
# Processing Record 43 of Set 2 | pevek
# Processing Record 44 of Set 2 | kolvereid
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 2 | pemangkat
# Processing Record 49 of Set 2 | sakaraha
# Processing Record 50 of Set 2 | erzin
# Processing Record 1 of Set 3 | atherton
# Processing Record 2 of Set 3 | kailua
# Processing Record 3 of Set 3 | marawi
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | banda aceh
# Processing Record 6 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 3 | severnyy
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | ust-omchug
# Processing Record 11 of Set 3 | tripoli
# Processing Record 12 of Set 3 | saint-pierre
# Processing Record 13 of Set 3 | piopio
# Processing Record 14 of Set 3 | hami
# Processing Record 15 of Set 3 | port hawkesbury
# Processing Record 16 of Set 3 | zaria
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | eureka
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | pianco
# Processing Record 24 of Set 3 | karla
# Processing Record 25 of Set 3 | hovd
# Processing Record 26 of Set 3 | marsh harbour
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | araouane
# Processing Record 29 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 3 | kralendijk
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | pangani
# Processing Record 33 of Set 3 | gravdal
# Processing Record 34 of Set 3 | bilma
# Processing Record 35 of Set 3 | panjab
# Processing Record 36 of Set 3 | vila velha
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | palestina
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | bucerias
# Processing Record 41 of Set 3 | san carlos de bariloche
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | kapit
# Processing Record 44 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 3 | klaksvik
# Processing Record 46 of Set 3 | suez
# Processing Record 47 of Set 3 | praya
# Processing Record 48 of Set 3 | matagalpa
# Processing Record 49 of Set 3 | manokwari
# Processing Record 50 of Set 3 | isabela
# Processing Record 1 of Set 4 | castro
# Processing Record 2 of Set 4 | kupang
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | college
# Processing Record 5 of Set 4 | wilmington
# Processing Record 6 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 4 | muscat
# Processing Record 8 of Set 4 | anadyr
# Processing Record 9 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | port hedland
# Processing Record 12 of Set 4 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 4 | oranjemund
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | sangar
# Processing Record 17 of Set 4 | vostok
# Processing Record 18 of Set 4 | seoul
# Processing Record 19 of Set 4 | loukhi
# Processing Record 20 of Set 4 | kyzyl-suu
# Processing Record 21 of Set 4 | sayyan
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | oyama
# Processing Record 24 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 4 | sedalia
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | puerto colombia
# Processing Record 28 of Set 4 | aklavik
# Processing Record 29 of Set 4 | fort nelson
# Processing Record 30 of Set 4 | port blair
# Processing Record 31 of Set 4 | egvekinot
# Processing Record 32 of Set 4 | coos bay
# Processing Record 33 of Set 4 | axim
# Processing Record 34 of Set 4 | terrace
# Processing Record 35 of Set 4 | elda
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | los llanos de aridane
# Processing Record 41 of Set 4 | cadiz
# Processing Record 42 of Set 4 | kapaa
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | airai
# Processing Record 45 of Set 4 | tefe
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | alice town
# Processing Record 48 of Set 4 | surovikino
# Processing Record 49 of Set 4 | kissidougou
# Processing Record 50 of Set 4 | smithers
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | port hardy
# Processing Record 3 of Set 5 | uvat
# Processing Record 4 of Set 5 | auki
# Processing Record 5 of Set 5 | broome
# Processing Record 6 of Set 5 | fukue
# Processing Record 7 of Set 5 | thinadhoo
# Processing Record 8 of Set 5 | tomari
# Processing Record 9 of Set 5 | dombarovskiy
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | bilibino
# Processing Record 12 of Set 5 | solone
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | barabai
# Processing Record 15 of Set 5 | san luis
# Processing Record 16 of Set 5 | grand-santi
# Processing Record 17 of Set 5 | wewak
# Processing Record 18 of Set 5 | sibolga
# Processing Record 19 of Set 5 | zhengjiatun
# Processing Record 20 of Set 5 | upernavik
# Processing Record 21 of Set 5 | byron bay
# Processing Record 22 of Set 5 | lavrentiya
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | maykor
# Processing Record 25 of Set 5 | jablah
# Processing Record 26 of Set 5 | faya
# Processing Record 27 of Set 5 | brae
# Processing Record 28 of Set 5 | yokadouma
# Processing Record 29 of Set 5 | arys
# Processing Record 30 of Set 5 | khlevnoye
# Processing Record 31 of Set 5 | olot
# Processing Record 32 of Set 5 | hay river
# Processing Record 33 of Set 5 | aiken
# Processing Record 34 of Set 5 | oxford
# Processing Record 35 of Set 5 | guanica
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | itoman
# Processing Record 38 of Set 5 | umm kaddadah
# Processing Record 39 of Set 5 | shestakovo
# Processing Record 40 of Set 5 | nikolskoye
# Processing Record 41 of Set 5 | palasa
# Processing Record 42 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 5 | davila
# Processing Record 44 of Set 5 | tres arroyos
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | corn island
# Processing Record 48 of Set 5 | lisakovsk
# Processing Record 49 of Set 5 | borgarnes
# Processing Record 50 of Set 5 | kohat
# Processing Record 1 of Set 6 | adre
# Processing Record 2 of Set 6 | karpathos
# Processing Record 3 of Set 6 | portland
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | vallenar
# Processing Record 6 of Set 6 | afua
# Processing Record 7 of Set 6 | viking
# Processing Record 8 of Set 6 | cherskiy
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | cururupu
# Processing Record 11 of Set 6 | nuuk
# Processing Record 12 of Set 6 | shingu
# Processing Record 13 of Set 6 | isangel
# Processing Record 14 of Set 6 | manono
# Processing Record 15 of Set 6 | lompoc
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 18 of Set 6 | saint george
# Processing Record 19 of Set 6 | kuryk
# Processing Record 20 of Set 6 | lorengau
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | vanavara
# Processing Record 24 of Set 6 | letlhakane
# Processing Record 25 of Set 6 | naron
# Processing Record 26 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 6 | kidal
# Processing Record 28 of Set 6 | goksun
# Processing Record 29 of Set 6 | bekhtery
# Processing Record 30 of Set 6 | mount gambier
# Processing Record 31 of Set 6 | norman wells
# Processing Record 32 of Set 6 | cairns
# Processing Record 33 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 6 | abu samrah
# Processing Record 35 of Set 6 | manaure
# Processing Record 36 of Set 6 | ko samui
# Processing Record 37 of Set 6 | numan
# Processing Record 38 of Set 6 | neuquen
# Processing Record 39 of Set 6 | caravelas
# Processing Record 40 of Set 6 | cabedelo
# Processing Record 41 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 6 | belmonte
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | kavaratti
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | raudeberg
# Processing Record 47 of Set 6 | sezze
# Processing Record 48 of Set 6 | yar-sale
# Processing Record 49 of Set 6 | choix
# Processing Record 50 of Set 6 | fairbanks
# Processing Record 1 of Set 7 | yangjiang
# Processing Record 2 of Set 7 | amga
# Processing Record 3 of Set 7 | abu road
# Processing Record 4 of Set 7 | loei
# Processing Record 5 of Set 7 | zhigansk
# Processing Record 6 of Set 7 | xique-xique
# Processing Record 7 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 7 | bandarbeyla
# Processing Record 9 of Set 7 | quatre cocos
# Processing Record 10 of Set 7 | chardara
# Processing Record 11 of Set 7 | hwange
# Processing Record 12 of Set 7 | ixtapa
# Processing Record 13 of Set 7 | hecun
# Processing Record 14 of Set 7 | menongue
# Processing Record 15 of Set 7 | mouila
# Processing Record 16 of Set 7 | cidreira
# Processing Record 17 of Set 7 | sola
# Processing Record 18 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 7 | dunedin
# Processing Record 20 of Set 7 | bedford
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | tono
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | frolovo
# Processing Record 25 of Set 7 | mitsamiouli
# Processing Record 26 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 27 of Set 7 | nangong
# Processing Record 28 of Set 7 | astana
# Processing Record 29 of Set 7 | vestmannaeyjar
# Processing Record 30 of Set 7 | makakilo city
# Processing Record 31 of Set 7 | zhangjiakou
# Processing Record 32 of Set 7 | flin flon
# Processing Record 33 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 7 | soyo
# Processing Record 35 of Set 7 | lokoja
# Processing Record 36 of Set 7 | ballina
# Processing Record 37 of Set 7 | puro
# Processing Record 38 of Set 7 | tshela
# Processing Record 39 of Set 7 | nakama
# Processing Record 40 of Set 7 | katsuura
# Processing Record 41 of Set 7 | cayenne
# Processing Record 42 of Set 7 | chugunash
# City not found. Skipping...
# Processing Record 43 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 7 | innerleithen
# Processing Record 45 of Set 7 | katav-ivanovsk
# Processing Record 46 of Set 7 | malanje
# Processing Record 47 of Set 7 | porangatu
# Processing Record 48 of Set 7 | polyarnyy
# Processing Record 49 of Set 7 | ginda
# Processing Record 50 of Set 7 | hambantota
# Processing Record 1 of Set 8 | jhawarian
# Processing Record 2 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 8 | idlib
# Processing Record 4 of Set 8 | buala
# Processing Record 5 of Set 8 | kalaleh
# Processing Record 6 of Set 8 | alcaniz
# Processing Record 7 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 8 | hammerfest
# Processing Record 9 of Set 8 | boca do acre
# Processing Record 10 of Set 8 | shenjiamen
# Processing Record 11 of Set 8 | necochea
# Processing Record 12 of Set 8 | cankuzo
# Processing Record 13 of Set 8 | kaeo
# Processing Record 14 of Set 8 | churapcha
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | iwaki
# Processing Record 17 of Set 8 | umba
# Processing Record 18 of Set 8 | archidona
# Processing Record 19 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 8 | alofi
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | hithadhoo
# Processing Record 23 of Set 8 | moron
# Processing Record 24 of Set 8 | kununurra
# Processing Record 25 of Set 8 | bonavista
# Processing Record 26 of Set 8 | lasa
# Processing Record 27 of Set 8 | uribia
# Processing Record 28 of Set 8 | pirai do sul
# Processing Record 29 of Set 8 | pedernales
# Processing Record 30 of Set 8 | young
# Processing Record 31 of Set 8 | bijar
# Processing Record 32 of Set 8 | seymchan
# Processing Record 33 of Set 8 | batagay
# Processing Record 34 of Set 8 | neiafu
# Processing Record 35 of Set 8 | rapid city
# Processing Record 36 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 37 of Set 8 | urumqi
# Processing Record 38 of Set 8 | camocim
# Processing Record 39 of Set 8 | souillac
# Processing Record 40 of Set 8 | mar del plata
# Processing Record 41 of Set 8 | yomou
# Processing Record 42 of Set 8 | dodge city
# Processing Record 43 of Set 8 | miandrivazo
# Processing Record 44 of Set 8 | vila franca do campo
# Processing Record 45 of Set 8 | hot springs
# Processing Record 46 of Set 8 | opuwo
# Processing Record 47 of Set 8 | lethem
# Processing Record 48 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 8 | nioki
# Processing Record 50 of Set 8 | san cristobal
# Processing Record 1 of Set 9 | provideniya
# Processing Record 2 of Set 9 | dorado
# Processing Record 3 of Set 9 | severo-kurilsk
# Processing Record 4 of Set 9 | comodoro rivadavia
# Processing Record 5 of Set 9 | manta
# Processing Record 6 of Set 9 | beruwala
# Processing Record 7 of Set 9 | bireun
# Processing Record 8 of Set 9 | christchurch
# Processing Record 9 of Set 9 | oranjestad
# Processing Record 10 of Set 9 | xining
# Processing Record 11 of Set 9 | schruns
# Processing Record 12 of Set 9 | iskateley
# Processing Record 13 of Set 9 | mayo
# Processing Record 14 of Set 9 | atar
# Processing Record 15 of Set 9 | mezen
# Processing Record 16 of Set 9 | venice
# Processing Record 17 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 18 of Set 9 | san rafael
# Processing Record 19 of Set 9 | bodden town
# Processing Record 20 of Set 9 | laguna
# Processing Record 21 of Set 9 | port macquarie
# Processing Record 22 of Set 9 | san quintin
# Processing Record 23 of Set 9 | ishlei
# City not found. Skipping...
# Processing Record 24 of Set 9 | tezu
# Processing Record 25 of Set 9 | nanchong
# Processing Record 26 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 9 | antofagasta
# Processing Record 28 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 9 | lomza
# Processing Record 30 of Set 9 | businga
# Processing Record 31 of Set 9 | san policarpo
# Processing Record 32 of Set 9 | haines junction
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | poya
# Processing Record 35 of Set 9 | daru
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | atasu
# Processing Record 38 of Set 9 | dicabisagan
# Processing Record 39 of Set 9 | micheweni
# Processing Record 40 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 9 | dano
# Processing Record 42 of Set 9 | otjiwarongo
# Processing Record 43 of Set 9 | leshukonskoye
# Processing Record 44 of Set 9 | melfi
# Processing Record 45 of Set 9 | linxi
# Processing Record 46 of Set 9 | barrow
# Processing Record 47 of Set 9 | san pedro
# Processing Record 48 of Set 9 | barbastro
# Processing Record 49 of Set 9 | moa
# Processing Record 50 of Set 9 | kathu
# Processing Record 1 of Set 10 | mokhsogollokh
# Processing Record 2 of Set 10 | price
# Processing Record 3 of Set 10 | nan
# Processing Record 4 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 10 | znamenskoye
# Processing Record 6 of Set 10 | sur
# Processing Record 7 of Set 10 | fonte boa
# Processing Record 8 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 9 of Set 10 | killybegs
# Processing Record 10 of Set 10 | kuantan
# Processing Record 11 of Set 10 | halifax
# Processing Record 12 of Set 10 | mayor pablo lagerenza
# Processing Record 13 of Set 10 | ilulissat
# Processing Record 14 of Set 10 | vanderhoof
# Processing Record 15 of Set 10 | halvad
# Processing Record 16 of Set 10 | luganville
# Processing Record 17 of Set 10 | tonota
# Processing Record 18 of Set 10 | husavik
# Processing Record 19 of Set 10 | chateau-gontier
# Processing Record 20 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 10 | wucheng
# Processing Record 22 of Set 10 | walvis bay
# Processing Record 23 of Set 10 | finschhafen
# Processing Record 24 of Set 10 | xai-xai
# Processing Record 25 of Set 10 | mogadishu
# Processing Record 26 of Set 10 | novyy urengoy
# Processing Record 27 of Set 10 | rumford
# Processing Record 28 of Set 10 | tucurui
# Processing Record 29 of Set 10 | yanam
# Processing Record 30 of Set 10 | tibati
# Processing Record 31 of Set 10 | ruteng
# Processing Record 32 of Set 10 | nhulunbuy
# Processing Record 33 of Set 10 | kayerkan
# Processing Record 34 of Set 10 | pavlogradka
# Processing Record 35 of Set 10 | golden
# Processing Record 36 of Set 10 | tampin
# Processing Record 37 of Set 10 | balkhash
# Processing Record 38 of Set 10 | palmer
# Processing Record 39 of Set 10 | coruripe
# Processing Record 40 of Set 10 | yining
# Processing Record 41 of Set 10 | yerbogachen
# Processing Record 42 of Set 10 | nanortalik
# Processing Record 43 of Set 10 | sao felix do xingu
# Processing Record 44 of Set 10 | zeitz
# Processing Record 45 of Set 10 | jackson
# Processing Record 46 of Set 10 | tateyama
# Processing Record 47 of Set 10 | tazovskiy
# Processing Record 48 of Set 10 | tshikapa
# Processing Record 49 of Set 10 | ishigaki
# Processing Record 50 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 11 | asau
# Processing Record 2 of Set 11 | goderich
# Processing Record 3 of Set 11 | mujiayingzi
# Processing Record 4 of Set 11 | pavlovsk
# Processing Record 5 of Set 11 | galeana
# Processing Record 6 of Set 11 | pierre
# Processing Record 7 of Set 11 | alamosa
# Processing Record 8 of Set 11 | port moresby
# Processing Record 9 of Set 11 | phetchaburi
# Processing Record 10 of Set 11 | olafsvik
# Processing Record 11 of Set 11 | burica
# City not found. Skipping...
# Processing Record 12 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 13 of Set 11 | ambulu
# Processing Record 14 of Set 11 | maniitsoq
# Processing Record 15 of Set 11 | akyab
# Processing Record 16 of Set 11 | mangrol
# Processing Record 17 of Set 11 | san miguel
# Processing Record 18 of Set 11 | mengen
# Processing Record 19 of Set 11 | ugoofaaru
# Processing Record 20 of Set 11 | rajgarh
# Processing Record 21 of Set 11 | capaci
# Processing Record 22 of Set 11 | fergus falls
# Processing Record 23 of Set 11 | nabire
# Processing Record 24 of Set 11 | basoko
# Processing Record 25 of Set 11 | camopi
# Processing Record 26 of Set 11 | nisia floresta
# Processing Record 27 of Set 11 | mumford
# Processing Record 28 of Set 11 | mehamn
# Processing Record 29 of Set 11 | hun
# Processing Record 30 of Set 11 | san antero
# Processing Record 31 of Set 11 | gazojak
# Processing Record 32 of Set 11 | mount isa
# Processing Record 33 of Set 11 | alzamay
# Processing Record 34 of Set 11 | kizukuri
# Processing Record 35 of Set 11 | wanning
# Processing Record 36 of Set 11 | taveta
# Processing Record 37 of Set 11 | sinnamary
# Processing Record 38 of Set 11 | dubbo
# Processing Record 39 of Set 11 | aranos
# Processing Record 40 of Set 11 | kilindoni
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | saint-augustin
# Processing Record 43 of Set 11 | constitucion
# Processing Record 44 of Set 11 | aykhal
# Processing Record 45 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 11 | omboue
# Processing Record 47 of Set 11 | abha
# Processing Record 48 of Set 11 | coihaique
# Processing Record 49 of Set 11 | kirakira
# Processing Record 50 of Set 11 | matara
# Processing Record 1 of Set 12 | touros
# Processing Record 2 of Set 12 | eskil
# Processing Record 3 of Set 12 | lata
# Processing Record 4 of Set 12 | tura
# Processing Record 5 of Set 12 | saint anthony
# Processing Record 6 of Set 12 | wattegama
# Processing Record 7 of Set 12 | pemba
# Processing Record 8 of Set 12 | kudahuvadhoo
# Processing Record 9 of Set 12 | pangoa
# Processing Record 10 of Set 12 | sovkhoznyy
# Processing Record 11 of Set 12 | kunya
# Processing Record 12 of Set 12 | molteno
# Processing Record 13 of Set 12 | maarianhamina
# Processing Record 14 of Set 12 | magaria
# Processing Record 15 of Set 12 | prieska
# Processing Record 16 of Set 12 | nanzhang
# Processing Record 17 of Set 12 | poum
# Processing Record 18 of Set 12 | takoradi
# Processing Record 19 of Set 12 | saint-louis
# Processing Record 20 of Set 12 | morondava
# Processing Record 21 of Set 12 | bukama
# Processing Record 22 of Set 12 | itarema
# Processing Record 23 of Set 12 | clyde river
# Processing Record 24 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 25 of Set 12 | diez
# Processing Record 26 of Set 12 | najran
# Processing Record 27 of Set 12 | yumen
# Processing Record 28 of Set 12 | flinders
# Processing Record 29 of Set 12 | ndele
# Processing Record 30 of Set 12 | grand gaube
# Processing Record 31 of Set 12 | nazca
# Processing Record 32 of Set 12 | iracoubo
# Processing Record 33 of Set 12 | pirenopolis
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | ploufragan
# Processing Record 36 of Set 12 | remiremont
# Processing Record 37 of Set 12 | taltal
# Processing Record 38 of Set 12 | alta
# Processing Record 39 of Set 12 | pak chong
# Processing Record 40 of Set 12 | ulcinj
# Processing Record 41 of Set 12 | mandurah
# Processing Record 42 of Set 12 | lugo
# Processing Record 43 of Set 12 | guerrero negro
# Processing Record 44 of Set 12 | sobolevo
# Processing Record 45 of Set 12 | qaqortoq
# Processing Record 46 of Set 12 | coffs harbour
# Processing Record 47 of Set 12 | belen
# Processing Record 48 of Set 12 | prince rupert
# Processing Record 49 of Set 12 | dalby
# Processing Record 50 of Set 12 | ati
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | ozd
# Processing Record 3 of Set 13 | mandan
# Processing Record 4 of Set 13 | atambua
# Processing Record 5 of Set 13 | tual
# Processing Record 6 of Set 13 | harper
# Processing Record 7 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 13 | mataram
# Processing Record 9 of Set 13 | joshimath
# Processing Record 10 of Set 13 | vanimo
# Processing Record 11 of Set 13 | maamba
# Processing Record 12 of Set 13 | narsaq
# Processing Record 13 of Set 13 | itaituba
# Processing Record 14 of Set 13 | whitehaven
# Processing Record 15 of Set 13 | evensk
# Processing Record 16 of Set 13 | berlevag
# Processing Record 17 of Set 13 | popondetta
# Processing Record 18 of Set 13 | bontang
# Processing Record 19 of Set 13 | elhovo
# Processing Record 20 of Set 13 | jasper
# Processing Record 21 of Set 13 | vieux-habitants
# Processing Record 22 of Set 13 | srikakulam
# Processing Record 23 of Set 13 | puerto escondido
# Processing Record 24 of Set 13 | marzuq
# Processing Record 25 of Set 13 | hokitika
# Processing Record 26 of Set 13 | quesnel
# Processing Record 27 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 13 | saint-junien
# Processing Record 29 of Set 13 | gracac
# Processing Record 30 of Set 13 | bam
# Processing Record 31 of Set 13 | santa maria
# Processing Record 32 of Set 13 | maumere
# Processing Record 33 of Set 13 | hirara
# Processing Record 34 of Set 13 | west wendover
# Processing Record 35 of Set 13 | westport
# Processing Record 36 of Set 13 | teya
# Processing Record 37 of Set 13 | road town
# Processing Record 38 of Set 13 | panacan
# Processing Record 39 of Set 13 | wangqing
# Processing Record 40 of Set 13 | ojinaga
# Processing Record 41 of Set 13 | keti bandar
# Processing Record 42 of Set 13 | nouadhibou
# Processing Record 43 of Set 13 | hvide sande
# Processing Record 44 of Set 13 | corinth
# Processing Record 45 of Set 13 | yaan
# Processing Record 46 of Set 13 | slave lake
# Processing Record 47 of Set 13 | acarau
# Processing Record 48 of Set 13 | visnes
# Processing Record 49 of Set 13 | baiquan
# Processing Record 50 of Set 13 | north platte
# Processing Record 1 of Set 14 | mosetse
# Processing Record 2 of Set 14 | lima
# Processing Record 3 of Set 14 | quepos
# Processing Record 4 of Set 14 | osterburg
# Processing Record 5 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 14 | ankang
# Processing Record 7 of Set 14 | howard springs
# Processing Record 8 of Set 14 | san patricio
# Processing Record 9 of Set 14 | roura
# Processing Record 10 of Set 14 | gimli
# Processing Record 11 of Set 14 | aarup
# City not found. Skipping...
# Processing Record 12 of Set 14 | tari
# Processing Record 13 of Set 14 | buckeye
# Processing Record 14 of Set 14 | mitzic
# Processing Record 15 of Set 14 | ardino
# Processing Record 16 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 17 of Set 14 | sug-aksy
# City not found. Skipping...
# Processing Record 18 of Set 14 | bogande
# Processing Record 19 of Set 14 | asfi
# Processing Record 20 of Set 14 | koumra
# Processing Record 21 of Set 14 | kenai
# Processing Record 22 of Set 14 | jiujiang
# Processing Record 23 of Set 14 | cascais
# Processing Record 24 of Set 14 | lewistown
# Processing Record 25 of Set 14 | mareeba
# Processing Record 26 of Set 14 | chifeng
# Processing Record 27 of Set 14 | santa catarina de tepehuanes
# Processing Record 28 of Set 14 | chisec
# Processing Record 29 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 14 | solnechnyy
# Processing Record 31 of Set 14 | shizunai
# Processing Record 32 of Set 14 | shouguang
# Processing Record 33 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 14 | barentu
# Processing Record 35 of Set 14 | cooma
# Processing Record 36 of Set 14 | ust-maya
# Processing Record 37 of Set 14 | xacmaz
# Processing Record 38 of Set 14 | ossora
# Processing Record 39 of Set 14 | tucuma
# Processing Record 40 of Set 14 | ilo
# Processing Record 41 of Set 14 | lufilufi
# Processing Record 42 of Set 14 | bereda
# Processing Record 43 of Set 14 | ronne
# Processing Record 44 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 45 of Set 14 | umm lajj
# Processing Record 46 of Set 14 | saint-leu
# Processing Record 47 of Set 14 | luzhou
# Processing Record 48 of Set 14 | morros
# Processing Record 49 of Set 14 | ayabaca
# Processing Record 50 of Set 14 | stromness
# Processing Record 1 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 15 | hobyo
# Processing Record 3 of Set 15 | kainantu
# Processing Record 4 of Set 15 | rawatsar
# Processing Record 5 of Set 15 | rawson
# Processing Record 6 of Set 15 | alice springs
# Processing Record 7 of Set 15 | ceres
# Processing Record 8 of Set 15 | salinopolis
# Processing Record 9 of Set 15 | avera
# Processing Record 10 of Set 15 | havre-saint-pierre
# Processing Record 11 of Set 15 | trairi
# Processing Record 12 of Set 15 | santa cruz
# Processing Record 13 of Set 15 | sarangani
# Processing Record 14 of Set 15 | teguldet
# Processing Record 15 of Set 15 | lunenburg
# Processing Record 16 of Set 15 | zyryanka
# Processing Record 17 of Set 15 | indramayu
# Processing Record 18 of Set 15 | celestun
# Processing Record 19 of Set 15 | tara
# Processing Record 20 of Set 15 | bojnurd
# Processing Record 21 of Set 15 | magadan
# Processing Record 22 of Set 15 | sao manuel
# Processing Record 23 of Set 15 | korla
# Processing Record 24 of Set 15 | zhanaozen
# Processing Record 25 of Set 15 | fare
# Processing Record 26 of Set 15 | alpena
# Processing Record 27 of Set 15 | tak
# Processing Record 28 of Set 15 | hofn
# Processing Record 29 of Set 15 | robertson
# Processing Record 30 of Set 15 | tambovka
# Processing Record 31 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 32 of Set 15 | abay
# Processing Record 33 of Set 15 | buraydah
# Processing Record 34 of Set 15 | lhokseumawe
# Processing Record 35 of Set 15 | senneterre
# Processing Record 36 of Set 15 | half moon bay
# Processing Record 37 of Set 15 | jiazi
# Processing Record 38 of Set 15 | meadow lake
# Processing Record 39 of Set 15 | hoa binh
# Processing Record 40 of Set 15 | fevralsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Paranaiba      BR -19.6772  -51.1908     85.60        24           0
# 1           Bowen      AU -20.0167  148.2333     62.92        88         100
# 2          Atuona      PF  -9.8000 -139.0333     75.78        80          25
# 3      Brigantine      US  39.4101  -74.3646     85.19        67           0
# 4     Port Alfred      ZA -33.5906   26.8910     58.17        67          29
# 5     Blytheville      US  35.9273  -89.9190     78.73        88          75
# 6            Gizo      SB  -8.1030  156.8419     81.72        76           3
# 7           Aswan      EG  24.0934   32.9070    105.13         9          20
# 8  Saint-Philippe      RE -21.3585   55.7679     71.19        81          45
# 9       Catamarca      AR -28.4696  -65.7852     68.77        33           0
#
#    Wind Speed Current Description
# 0        6.11           clear sky
# 1        8.59     overcast clouds
# 2       11.43          light rain
# 3        5.75           clear sky
# 4        5.01    scattered clouds
# 5        6.91       broken clouds
# 6       10.78           clear sky
# 7       13.51          few clouds
# 8       14.76          light rain
# 9        5.30           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
